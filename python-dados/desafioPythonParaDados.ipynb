# %% [markdown]
# # Python para Dados - Desafio Final
# Bootcamp Data Analytics 2024
#
# Ludmylla Martins Caetano -- Squad Rita Levi Montalcini

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Considerando a base de dados de saude_do_sono_estilo_vida.csv responda as questões abaixo.
#
# Você é uma pesquisadora que está tentando entender melhor qual o impacto do estilo de vida de uma pessoa na sua qualidade de sono, por isso fez a coleta dos dados de sobre 373 pessoas, onde foram recolhidas 12 características para cada uma delas. Por competência a sua pesquisa foi bem controlada e você não tem dados faltosos na sua base. Chegou o momento de você fazer sua análise e responder algumas perguntas.

# %%
#carregando o arquivo csv
df_saude = pd.read_csv("saude_do_sono_estilo_vida.csv")
df_saude
# Out:
#       ID  Gênero  Idade                 Ocupação  Duração do sono  \
# 0      1   Homem     27         Eng. de Software              6.1
# 1      2   Homem     28                Médico(a)              6.2
# 2      3   Homem     28                Médico(a)              6.2
# 3      4   Homem     28  Representante de Vendas              5.9
# 4      5   Homem     28  Representante de Vendas              5.9
# ..   ...     ...    ...                      ...              ...
# 368  369  Mulher     59            Enfermeiro(a)              8.1
# 369  370  Mulher     59            Enfermeiro(a)              8.1
# 370  371  Mulher     59            Enfermeiro(a)              8.0
# 371  372  Mulher     59            Enfermeiro(a)              8.1
# 372  373  Mulher     59            Enfermeiro(a)              8.1
#
#      Qualidade do sono  Nível de atividade física  Nível de estresse  \
# 0                    6                         42                  6
# ...

# %%
#1. Ao visualizar a base você percebeu que seria melhor alterar o nome de algumas colunas. Mude o ‘ID’ para ‘Identificador’, corrija o nome da coluna que
#indica a pressão sanguínea, mude a coluna ‘Ocupação’ para ‘Profissão’, a coluna ‘Categoria BMI’ está em parte em inglês, substitua para ‘Categoria IMC’.
df_saude = df_saude.rename(columns={'ID': 'Identificador', 'Pressão sanguíneaaaa':'Pressão sanguínea', 'Ocupação': 'Profissão', 'Categoria BMI': 'Categoria IMC'})
df_saude.head()
# Out:
#    Identificador Gênero  Idade                Profissão  Duração do sono  \
# 0              1  Homem     27         Eng. de Software              6.1
# 1              2  Homem     28                Médico(a)              6.2
# 2              3  Homem     28                Médico(a)              6.2
# 3              4  Homem     28  Representante de Vendas              5.9
# 4              5  Homem     28  Representante de Vendas              5.9
#
#    Qualidade do sono  Nível de atividade física  Nível de estresse  \
# 0                  6                         42                  6
# 1                  6                         60                  8
# 2                  6                         60                  8
# 3                  4                         30                  8
# 4                  4                         30                  8
#
#   Categoria IMC Pressão sanguínea  Frequência cardíaca  Passos diários  \
# ...

# %%
#2. Qual é a média, a moda e a mediana de horas de sono para cada uma das profissões? [‘mean’, np.median, pd.Series.mod]
tabela = df_saude.pivot_table(values="Duração do sono", index="Profissão", aggfunc= [np.mean, np.median, pd.Series.mode])
tabela.columns = ['Média', 'Mediana', 'Moda']
tabela
# Out:
#                             Média  Mediana        Moda
# Profissão
# Advogado(a)              7.410638      7.3         7.2
# Cientista                6.000000      6.0  [5.8, 6.2]
# Contador(a)              7.113514      7.2         7.2
# Enfermeiro(a)            7.048611      6.5         6.1
# Eng. de Software         6.750000      6.8         7.5
# Engenheiro(a)            7.987302      8.3         8.4
# Gerente                  6.900000      6.9         6.9
# Médico(a)                6.970423      7.6         6.0
# Pessoa Vendendora        6.403125      6.4         6.5
# Professor(a)             6.690000      6.6         6.6
# Representante de Vendas  5.900000      5.9         5.9

# %%
#3. Das pessoas que atuam com engenharia de software qual a porcentagem de obesos?
obesos = len(df_saude[(df_saude['Profissão'] == 'Eng. de Software') & (df_saude['Categoria IMC'] == 'Obesidade')])
total = (df_saude['Profissão'] == 'Eng. de Software').sum()
print(f'{(obesos/total)*100}%')
# Out:
# 25.0%

# %%
#4. De acordo com os dados, advogar ou ser representante de vendas faz você dormir menos? (Use o método ‘isin’, considere a média)
df_adv_rv = df_saude['Profissão'].isin(['Advogado(a)', 'Representante de Vendas'])
print(df_saude[df_adv_rv]['Duração do sono'].mean())
print('Não faz dormir menos')
# Out:
# 7.348979591836734
# Não faz dormir menos

# %%
#5. Entre quem fez enfermagem e quem fez medicina, quem tem menos horas de sono? (Use o método ‘isin’, considere a média)
horas_sono_enfermeiro = df_saude[df_saude['Profissão'].isin(['Enfermeiro(a)'])]['Duração do sono'].mean()
horas_sono_medico = df_saude[df_saude['Profissão'].isin(['Médico(a)'])]['Duração do sono'].mean()

if (horas_sono_enfermeiro > horas_sono_medico):
  print("Médico(a) tem menos horas de sono.")
else:
  print("Enfermeiro(a) tem menos horas de sono.")
# Out:
# Médico(a) tem menos horas de sono.

# %%
#6. Faça um subconjunto com as colunas Identificador, Gênero, Idade, Pressão sanguínea e Frequência cardíaca.
df_saude_corte = df_saude[['Identificador', 'Gênero', 'Idade', 'Pressão sanguínea', 'Frequência cardíaca']]
df_saude_corte.head()
# Out:
#    Identificador Gênero  Idade Pressão sanguínea  Frequência cardíaca
# 0              1  Homem     27            126/83                   77
# 1              2  Homem     28            125/80                   75
# 2              3  Homem     28            125/80                   75
# 3              4  Homem     28            140/90                   85
# 4              5  Homem     28            140/90                   85

# %%
#7. Descubra qual a profissão menos frequente no conjunto. (Use value_counts)
prof_menos_frequente = df_saude['Profissão'].value_counts().idxmin()
prof_menos_frequente
# Out:
# 'Gerente'

# %%
#8. Quem tem maior pressão sanguínea média, homens ou mulheres? (Considere a média)
df_saude[['Pressão sistólica', 'Pressão diastólica']] = df_saude['Pressão sanguínea'].str.split('/', n = 1, expand = True).astype(int)
df_saude['Pressão arterial média'] = (df_saude['Pressão sistólica'] + 2 * df_saude['Pressão diastólica']) / 3
df_saude.head()
maior_pressao = df_saude.groupby('Gênero')['Pressão arterial média'].mean().idxmax()
maior_pressao
# Out:
# 'Mulher'

# %%
#9. É predominante entre os participantes dormir 8 horas por dia (considere usar Moda como medida)?
dormem_oitoh = (df_saude['Duração do sono'] == 8).sum()
horas_dormidas = df_saude['Duração do sono'].mode().sum()
print(f'É predominante os participantes dormirem {horas_dormidas}h por dia. Apenas {dormem_oitoh} participantes dormem 8 horas por dia.')
# Out:
# É predominante os participantes dormirem 7.2h por dia. Apenas 13 participantes dormem 8 horas por dia.

# %%
#10. Pessoas com frequências cardíacas acima de 70 dão mais passos que pessoas com frequência cardíaca menor ou igual a 70? (Use a média)
freq_acima = df_saude[df_saude['Frequência cardíaca'] > 70]['Passos diários'].mean()
freq_abaixo = df_saude[df_saude['Frequência cardíaca'] <= 70]['Passos diários'].mean()

if(freq_acima>freq_abaixo):
  print('Pessoas com frequências cardíacas acima de 70 dão mais passos que pessoas com frequência cardíaca menor ou igual a 70.')
else:
  print('Pessoas com frequências cardíacas acima de 70 não dão mais passos que pessoas com frequência cardíaca menor ou igual a 70.')
# Out:
# Pessoas com frequências cardíacas acima de 70 não dão mais passos que pessoas com frequência cardíaca menor ou igual a 70.
